# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing dataset
data_set=pd.read_csv("winequality-red.csv")
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1598 non-null   float64
#  4   chlorides             1598 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1598 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1594 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
data_set.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data_set.shape
# Out:
# (1599, 12)

# %%
data_set.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# ...

# %%
#checking for null values using isna and sum function
data_set.isna().sum()
# Out:
# fixed acidity           1
# volatile acidity        0
# citric acid             0
# residual sugar          1
# chlorides               1
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 0
# pH                      5
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#displaying various statistical properties
data_set.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1599.000000  1599.000000     1598.000000
# mean        8.320588          0.527821     0.270976        2.539330
# std         1.741226          0.179060     0.194801        1.410213
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1598.000000          1598.000000           1598.000000  1599.000000
# mean      0.087490            15.866083             46.468711     0.996747
# std       0.047071            10.457456             32.905601     0.001887
# ...

# %%
data_set.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
data_set[data_set.duplicated()] #checking for redundant rows
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
# ...

# %%
#dropping duplicate rows
data_set.drop_duplicates(inplace=True)

# %%
data_set.shape
# Out:
# (1359, 12)

# %%
data_set.isna().sum()
# Out:
# fixed acidity           1
# volatile acidity        0
# citric acid             0
# residual sugar          1
# chlorides               1
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 0
# pH                      5
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#displays unique values from column named quantity
data_set['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
updated_df = data_set.dropna(axis=0)
#drops either column or row
#axis=0 for rows
#axis=1 for columns

# %%
data_set.isna().sum()
# Out:
# fixed acidity           1
# volatile acidity        0
# citric acid             0
# residual sugar          1
# chlorides               1
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 0
# pH                      5
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#dropping the entire column sulphate from dataset
y1 = updated_df['sulphates']
updated_df.drop("sulphates",axis=1,inplace=True)
# Out:
# <ipython-input-76-4f8937a75cbc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   updated_df.drop("sulphates",axis=1,inplace=True)

# %%
updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1350 entries, 0 to 1598
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1350 non-null   float64
#  1   volatile acidity      1350 non-null   float64
#  2   citric acid           1350 non-null   float64
#  3   residual sugar        1350 non-null   float64
#  4   chlorides             1350 non-null   float64
#  5   free sulfur dioxide   1350 non-null   float64
#  6   total sulfur dioxide  1350 non-null   float64
#  7   density               1350 non-null   float64
#  8   pH                    1350 non-null   float64
#  9   alcohol               1350 non-null   float64
#  10  quality               1350 non-null   int64
# dtypes: float64(10), int64(1)
# memory usage: 126.6 KB

# %%
#handling missing values using mean in column pH
updated_df['pH']=updated_df['pH'].fillna(updated_df['pH'].mean())
updated_df.isna().sum()
# Out:
# fixed acidity           1
# volatile acidity        0
# citric acid             0
# residual sugar          1
# chlorides               1
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 0
# pH                      0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
updated_df['fixed acidity']=updated_df['fixed acidity'].fillna(updated_df['fixed acidity'].mean())
updated_df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          1
# chlorides               1
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 0
# pH                      0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#converting float to int
data_set[['alcohol']] = data_set[['alcohol']].astype(int)
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1359 entries, 0 to 1598
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1359 non-null   float64
#  1   volatile acidity      1359 non-null   float64
#  2   citric acid           1359 non-null   float64
#  3   residual sugar        1358 non-null   float64
#  4   chlorides             1358 non-null   float64
#  5   free sulfur dioxide   1358 non-null   float64
#  6   total sulfur dioxide  1358 non-null   float64
#  7   density               1359 non-null   float64
#  8   pH                    1359 non-null   float64
#  9   alcohol               1359 non-null   int64
#  10  quality               1359 non-null   int64
# dtypes: float64(9), int64(2)
# memory usage: 127.4 KB

# %%
#imputing the missing values using simpleImputer
from sklearn.impute import SimpleImputer
myimputer = SimpleImputer(strategy = 'median')
data_new = myimputer.fit_transform(updated_df)

# %%
updated_df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#finding correlation between variables
updated_df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.254698     0.668405
# volatile acidity          -0.254698          1.000000    -0.553008
# citric acid                0.668405         -0.553008     1.000000
# residual sugar             0.110842         -0.000367     0.144047
# chlorides                  0.085905          0.051175     0.211769
# free sulfur dioxide       -0.142677         -0.020217    -0.051052
# total sulfur dioxide      -0.105314          0.068057     0.044489
# density                    0.670315          0.024474     0.359358
# pH                        -0.687123          0.249753    -0.552169
# alcohol                   -0.063266         -0.194557     0.103189
# quality                    0.119424         -0.395092     0.229154
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.110842   0.085905            -0.142677
# ...

# %%
#heatmap represents the correlation of each variable pair with various colour codes
plt.figure(figsize=(10,8))
sns.heatmap(updated_df.corr(),annot=True)
# Out:
# <Axes: >

# %%
updated_df.quality.value_counts()
# Out:
# 5    570
# 6    534
# 7    166
# 4     53
# 8     17
# 3     10
# Name: quality, dtype: int64

# %%
#bar plot for quality column
updated_df.quality.value_counts().plot(kind ='bar')
# Out:
# <Axes: >

# %%
#Histograms  tools that represent the distribution of a set of continuous data.
for column in updated_df.columns:
    sns.histplot(updated_df[column],kde='true')

# %%
sns.histplot(updated_df['chlorides'])
# Out:
# <Axes: xlabel='chlorides', ylabel='Count'>

# %%
sns.scatterplot(x='alcohol',y='pH',hue='quality',data=updated_df)
# Out:
# <Axes: xlabel='alcohol', ylabel='pH'>

# %%
for i in updated_df.columns:
    plt.figure()
    sns.boxplot(y=i,data=updated_df)

# %%
sns.lineplot(x='pH',y='quality',data=updated_df)
# Out:
# <Axes: xlabel='pH', ylabel='quality'>

# %%
sns.pairplot(updated_df)
